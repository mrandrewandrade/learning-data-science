# %% [markdown]
# # 2.3.1 Visualizing Bivariate Distributions Homework Answer
#
# Data Science Field Guide
#
# Author: Andrew Andrade
#
# ## Homework
#
# Plot the remainder of the Anscombe's quartets.
#
# The links are the following:
#
# [anscombe_ii.csv](https://raw.githubusercontent.com/mrandrewandrade/learning-data-science/master/datasets/anscombe_ii.csv)
#
# [anscombe_iii.csv](https://raw.githubusercontent.com/mrandrewandrade/learning-data-science/master/datasets/anscombe_iii.csv)
#
# [anscombe_iv.csv](https://raw.githubusercontent.com/mrandrewandrade/learning-data-science/master/datasets/anscombe_iv.csv)
#
#
# ## Answer

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

anscombe_i = pd.read_csv('../datasets/anscombe_i.csv')
anscombe_ii = pd.read_csv('../datasets/anscombe_ii.csv')
anscombe_iii = pd.read_csv('../datasets/anscombe_iii.csv')
anscombe_iv = pd.read_csv('../datasets/anscombe_iv.csv')

# %%
plt.plot(anscombe_i)
# Out:
# [<matplotlib.lines.Line2D at 0x11291c8d0>,
#  <matplotlib.lines.Line2D at 0x11291cb10>]

# %%
sns.jointplot(x="x", y="y", data=anscombe_i)

# %%
plt.plot(anscombe_ii)
# Out:
# [<matplotlib.lines.Line2D at 0x112f4a490>,
#  <matplotlib.lines.Line2D at 0x112f4a6d0>]

# %%
sns.jointplot(x="x", y="y", data=anscombe_ii)

# %%
plt.plot(anscombe_iii)
# Out:
# [<matplotlib.lines.Line2D at 0x1131eb690>,
#  <matplotlib.lines.Line2D at 0x1131eb8d0>]

# %%
sns.jointplot(x="x", y="y", data=anscombe_iii)

# %%
plt.plot(anscombe_iv)
# Out:
# [<matplotlib.lines.Line2D at 0x113356350>,
#  <matplotlib.lines.Line2D at 0x113356590>]

# %%
sns.jointplot(x="x", y="y", data=anscombe_iv)
