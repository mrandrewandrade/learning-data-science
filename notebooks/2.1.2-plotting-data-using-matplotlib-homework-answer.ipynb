# %% [markdown]
# # 2.1.2 Plotting data using matplotlib Homework Answer
#
# Data Science Field Guide
#
# Author: Andrew Andrade
#
# ## Homework
#
# Use a scatter plot to plot the remainder of the Anscombe's quartet.
#
# The links are the following:
#
# [anscombe_ii.csv](https://raw.githubusercontent.com/mrandrewandrade/learning-data-science/master/datasets/anscombe_ii.csv)
#
# [anscombe_iii.csv](https://raw.githubusercontent.com/mrandrewandrade/learning-data-science/master/datasets/anscombe_iii.csv)
#
# [anscombe_iv.csv](https://raw.githubusercontent.com/mrandrewandrade/learning-data-science/master/datasets/anscombe_iv.csv)
#
# ## Answer
#
# Must haves:
#
# 1. Legend
# 2. Labeled Axis and Title
# 3. Labels on datasets
# 4. Visually distinguishable

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# load datasets
anscombe_i = pd.read_csv('../datasets/anscombe_i.csv')
anscombe_ii = pd.read_csv('../datasets/anscombe_ii.csv')
anscombe_iii = pd.read_csv('../datasets/anscombe_iii.csv')
anscombe_iv = pd.read_csv('../datasets/anscombe_iv.csv')


# calculate the mean and standard deviation for each
print "Data Set I"
print anscombe_i.describe()[1:3]
print "\n Data Set II"
print anscombe_ii.describe()[1:3]
print "\n Data Set III"
print anscombe_iii.describe()[1:3]
print "\n Data Set IV"
print anscombe_iv.describe()[1:3]


plt.scatter(anscombe_i["x"],anscombe_i["y"], label = "Dataset I", marker='.', color = 'black')
plt.scatter(anscombe_ii["x"],anscombe_ii["y"], label = "Dataset II", marker='*', color = 'green')
plt.scatter(anscombe_iii["x"],anscombe_iii["y"], label = "Dataset III",marker='^', color = 'pink')
plt.scatter(anscombe_iv["x"],anscombe_iv["y"], label = "Dataset IV",marker='v', color = 'blue')
plt.legend()

plt.xlabel("Measurement of X (unitless)")
plt.ylabel("Measurement of Y (unitless)")
plt.title("Y vs X for Anscombe's Quartet")
# Out:
# Data Set I
#              x         y
# mean  9.000000  7.500909
# std   3.316625  2.031568
#
#  Data Set II
#              x         y
# mean  9.000000  7.500909
# std   3.316625  2.031657
#
#  Data Set III
#              x         y
# mean  9.000000  7.500000
# std   3.316625  2.030424
#
#  Data Set IV
#              x         y
# mean  9.000000  7.500909
# std   3.316625  2.030579
